# %%
# 1. 폴더 이름을 짧은 zip 파일로 압축하는 명령어
# !zip -r result_download.zip "ethereum_analysismodel_results2025-11-10fold_resultsdirection_l8_p1.5_s1.0"
# Out:
# 	zip warning: name not matched: ethereum_analysismodel_results2025-11-10fold_resultsdirection_l8_p1.5_s1.0
#
# zip error: Nothing to do! (try: zip -r result_download.zip . -i ethereum_analysismodel_results2025-11-10fold_resultsdirection_l8_p1.5_s1.0)

# %%
# !ls
# Out:
# fold_1_walk_forward_rolling_reverse  fold_6_walk_forward_rolling_reverse
# fold_2_walk_forward_rolling_reverse  fold_7_walk_forward_rolling_reverse
# fold_3_walk_forward_rolling_reverse  fold_8_final_holdout
# fold_4_walk_forward_rolling_reverse  Untitled.ipynb
# fold_5_walk_forward_rolling_reverse
